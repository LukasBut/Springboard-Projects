# %% [markdown]
# #                    Question Answering Capstone Project - Reading in JSON/Data Wrangling

# %% [markdown]
# ### Importing Modules, Defining Custom Functions

# %%
import numpy as np
import pandas as pd

"""Extracts 'text' and 'answer_start' fields from the JSON to aid in creation of the pandas dataframe. It loops over the 
questions associated with a 'context' and depending on if it's an impossible question or not, reads the data appropriately.
The final 'else' statement deals with rare instances where the value of the 'plausible_answers' key is an empty list with no
'text' or 'answer_start fields'. Without the else, a 'ArrayIndexOutOfBoundsException is thrown'."""

def answer_data(context, impossible_question):
    dict_list=[]
    for question_idx in range(len(context["qas"])): # iterate over questions
        if impossible_question[question_idx]==False: # if question is answerable, all is ok, we read the data
            dict_list.append({"answer_text":context["qas"][question_idx]["answers"][0]["text"], 
                              "answer_start":context["qas"][question_idx]["answers"][0]["answer_start"]})
        elif impossible_question[question_idx]==True and len(context["qas"][question_idx]["plausible_answers"])!=0:
            dict_list.append({"answer_text":context["qas"][question_idx]["plausible_answers"][0]["text"],
                              "answer_start":context["qas"][question_idx]["plausible_answers"][0]["answer_start"]})
        else: # if 'plausible_answers' dict is an empty list
             dict_list.append({"answer_text":np.NaN, "answer_start":np.NaN})
    return dict_list

# %% [markdown]
# ### Importing and Structuring the Training Set

# %%
file=pd.read_json("https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json")[["data"]].to_json("train_file.json")
train_file=pd.read_json("train_file.json", orient="split").transpose().reset_index(drop=True)
train_file["title"]=train_file.loc[:,"title"].str.replace("_"," ")
train_themes=train_file["title"].values

# %%
# Creating dataframes for all themes within the training data set
train_df=pd.DataFrame()

# Looping over each theme in the JSON
for n_theme, theme in enumerate(train_themes):
    theme_contexts=train_file.iloc[n_theme,0] 
    theme_df=pd.DataFrame()
    # Going over all 'contexts' (paragraphs of data) within theme
    for context in theme_contexts:
        context_df=pd.DataFrame(data=context["qas"]).loc[:,["question", "id", "is_impossible"]] 
        context_df["context"]=context["context"]
        impossible_question=context_df["is_impossible"].values #boolean array to denote if given question of context is impossible
        context_df=context_df.join(pd.DataFrame(data=answer_data(context, impossible_question)))
        
        theme_df=theme_df.append(context_df, ignore_index=True)
        
    theme_df["title"]=theme
    train_df=train_df.append(theme_df, ignore_index=True) 
       
    # Some debugging/progress prints
    print("Added '%s' theme." % theme)
    print(n_theme+1,"/",len(train_themes), "  ------   ", (float(n_theme+1)/float(len(train_themes)))*100, "%")
    print(theme_df.info(),"\n")
   
print(train_df)
print(train_df.info())
# Out:
# Added 'Beyoncé' theme.
# 1 / 442   ------    0.22624434389140274 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 753 entries, 0 to 752
# Data columns (total 7 columns):
# question         753 non-null object
# id               753 non-null object
# is_impossible    753 non-null bool
# context          753 non-null object
# answer_start     753 non-null int64
# answer_text      753 non-null object
# title            753 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 36.1+ KB
# None
#
# Added 'Frédéric Chopin' theme.
# 2 / 442   ------    0.4524886877828055 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 697 entries, 0 to 696
# Data columns (total 7 columns):
# question         697 non-null object
# id               697 non-null object
# is_impossible    697 non-null bool
# context          697 non-null object
# answer_start     697 non-null int64
# answer_text      697 non-null object
# title            697 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 33.4+ KB
# None
#
# Added 'Kanye West' theme.
# 3 / 442   ------    0.6787330316742082 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 7 columns):
# question         428 non-null object
# id               428 non-null object
# is_impossible    428 non-null bool
# context          428 non-null object
# answer_start     428 non-null int64
# answer_text      428 non-null object
# title            428 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.6+ KB
# None
#
# Added 'MP3' theme.
# 4 / 442   ------    0.904977375565611 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 7 columns):
# question         289 non-null object
# id               289 non-null object
# is_impossible    289 non-null bool
# context          289 non-null object
# answer_start     289 non-null int64
# answer_text      289 non-null object
# title            289 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.9+ KB
# None
#
# Added 'House music' theme.
# 5 / 442   ------    1.1312217194570136 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 7 columns):
# question         420 non-null object
# id               420 non-null object
# is_impossible    420 non-null bool
# context          420 non-null object
# answer_start     420 non-null int64
# answer_text      420 non-null object
# title            420 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.2+ KB
# None
#
# Added 'Letter case' theme.
# 6 / 442   ------    1.3574660633484164 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 7 columns):
# question         55 non-null object
# id               55 non-null object
# is_impossible    55 non-null bool
# context          55 non-null object
# answer_start     55 non-null int64
# answer_text      55 non-null object
# title            55 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 2.7+ KB
# None
#
# Added 'Chihuahua (state)' theme.
# 7 / 442   ------    1.583710407239819 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 7 columns):
# question         306 non-null object
# id               306 non-null object
# is_impossible    306 non-null bool
# context          306 non-null object
# answer_start     306 non-null int64
# answer_text      306 non-null object
# title            306 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.7+ KB
# None
#
# Added 'Imamah (Shia doctrine)' theme.
# 8 / 442   ------    1.809954751131222 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 7 columns):
# question         64 non-null object
# id               64 non-null object
# is_impossible    64 non-null bool
# context          64 non-null object
# answer_start     64 non-null int64
# answer_text      64 non-null object
# title            64 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 3.1+ KB
# None
#
# Added 'Pitch (music)' theme.
# 9 / 442   ------    2.0361990950226243 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
# question         36 non-null object
# id               36 non-null object
# is_impossible    36 non-null bool
# context          36 non-null object
# answer_start     36 non-null int64
# answer_text      36 non-null object
# title            36 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 1.8+ KB
# None
#
# Added 'England national football team' theme.
# 10 / 442   ------    2.262443438914027 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 7 columns):
# question         119 non-null object
# id               119 non-null object
# is_impossible    119 non-null bool
# context          119 non-null object
# answer_start     119 non-null int64
# answer_text      119 non-null object
# title            119 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 5.8+ KB
# None
#
# Added 'Houston' theme.
# 11 / 442   ------    2.48868778280543 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
# question         521 non-null object
# id               521 non-null object
# is_impossible    521 non-null bool
# context          521 non-null object
# answer_start     521 non-null int64
# answer_text      521 non-null object
# title            521 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 25.0+ KB
# None
#
# Added 'Copper' theme.
# 12 / 442   ------    2.7149321266968327 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 7 columns):
# question         304 non-null object
# id               304 non-null object
# is_impossible    304 non-null bool
# context          304 non-null object
# answer_start     304 non-null int64
# answer_text      304 non-null object
# title            304 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.6+ KB
# None
#
# Added 'Identity (social science)' theme.
# 13 / 442   ------    2.941176470588235 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 7 columns):
# question         168 non-null object
# id               168 non-null object
# is_impossible    168 non-null bool
# context          168 non-null object
# answer_start     168 non-null int64
# answer_text      168 non-null object
# title            168 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 8.1+ KB
# None
#
# Added 'Buddhism' theme.
# 14 / 442   ------    3.167420814479638 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
# question         610 non-null object
# id               610 non-null object
# is_impossible    610 non-null bool
# context          610 non-null object
# answer_start     610 non-null int64
# answer_text      610 non-null object
# title            610 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 29.3+ KB
# None
#
# Added 'Himachal Pradesh' theme.
# 15 / 442   ------    3.3936651583710407 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 7 columns):
# question         226 non-null object
# id               226 non-null object
# is_impossible    226 non-null bool
# context          226 non-null object
# answer_start     226 non-null int64
# answer_text      226 non-null object
# title            226 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.9+ KB
# None
#
# Added 'Communication' theme.
# 16 / 442   ------    3.619909502262444 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 7 columns):
# question         117 non-null object
# id               117 non-null object
# is_impossible    117 non-null bool
# context          117 non-null object
# answer_start     117 non-null int64
# answer_text      117 non-null object
# title            117 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 5.7+ KB
# None
#
# Added 'Grape' theme.
# 17 / 442   ------    3.8461538461538463 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
# question         48 non-null object
# id               48 non-null object
# is_impossible    48 non-null bool
# context          48 non-null object
# answer_start     48 non-null int64
# answer_text      48 non-null object
# title            48 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 2.4+ KB
# None
# Added 'Computer security' theme.
# 18 / 442   ------    4.072398190045249 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
# question         365 non-null object
# id               365 non-null object
# is_impossible    365 non-null bool
# context          365 non-null object
# answer_start     365 non-null int64
# answer_text      365 non-null object
# title            365 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.5+ KB
# None
#
# Added 'Orthodox Judaism' theme.
# 19 / 442   ------    4.298642533936651 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
# question         240 non-null object
# id               240 non-null object
# is_impossible    240 non-null bool
# context          240 non-null object
# answer_start     240 non-null int64
# answer_text      240 non-null object
# title            240 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.6+ KB
# None
#
# Added 'Animal' theme.
# 20 / 442   ------    4.524886877828054 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
# question         79 non-null object
# id               79 non-null object
# is_impossible    79 non-null bool
# context          79 non-null object
# answer_start     79 non-null int64
# answer_text      79 non-null object
# title            79 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 3.9+ KB
# None
#
# Added 'Beer' theme.
# 21 / 442   ------    4.751131221719457 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 7 columns):
# question         339 non-null object
# id               339 non-null object
# is_impossible    339 non-null bool
# context          339 non-null object
# answer_start     339 non-null int64
# answer_text      339 non-null object
# title            339 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.3+ KB
# None
#
# Added 'Race and ethnicity in the United States Census' theme.
# 22 / 442   ------    4.97737556561086 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# question         52 non-null object
# id               52 non-null object
# is_impossible    52 non-null bool
# context          52 non-null object
# answer_start     52 non-null int64
# answer_text      52 non-null object
# title            52 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 2.6+ KB
# None
#
# Added 'United States dollar' theme.
# 23 / 442   ------    5.203619909502263 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 7 columns):
# question         319 non-null object
# id               319 non-null object
# is_impossible    319 non-null bool
# context          319 non-null object
# answer_start     319 non-null int64
# answer_text      319 non-null object
# title            319 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.3+ KB
# None
#
# Added 'Imperial College London' theme.
# 24 / 442   ------    5.429864253393665 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 7 columns):
# question         255 non-null object
# id               255 non-null object
# is_impossible    255 non-null bool
# context          255 non-null object
# answer_start     255 non-null int64
# answer_text      255 non-null object
# title            255 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.3+ KB
# None
#
# Added 'American Idol' theme.
# 25 / 442   ------    5.656108597285068 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 790 entries, 0 to 789
# Data columns (total 7 columns):
# question         790 non-null object
# id               790 non-null object
# is_impossible    790 non-null bool
# context          790 non-null object
# answer_start     790 non-null int64
# answer_text      790 non-null object
# title            790 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 37.9+ KB
# None
#
# Added 'Hanover' theme.
# 26 / 442   ------    5.88235294117647 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 7 columns):
# question         197 non-null object
# id               197 non-null object
# is_impossible    197 non-null bool
# context          197 non-null object
# answer_start     197 non-null int64
# answer_text      197 non-null object
# title            197 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.5+ KB
# None
#
# Added 'Emotion' theme.
# 27 / 442   ------    6.108597285067873 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 7 columns):
# question         375 non-null object
# id               375 non-null object
# is_impossible    375 non-null bool
# context          375 non-null object
# answer_start     375 non-null int64
# answer_text      375 non-null object
# title            375 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.0+ KB
# None
#
# Added 'Everton F.C.' theme.
# 28 / 442   ------    6.334841628959276 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 7 columns):
# question         230 non-null object
# id               230 non-null object
# is_impossible    230 non-null bool
# context          230 non-null object
# answer_start     230 non-null int64
# answer_text      230 non-null object
# title            230 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.1+ KB
# None
#
# Added 'Old English' theme.
# 29 / 442   ------    6.561085972850679 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 7 columns):
# question         187 non-null object
# id               187 non-null object
# is_impossible    187 non-null bool
# context          187 non-null object
# answer_start     187 non-null int64
# answer_text      187 non-null object
# title            187 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.0+ KB
# None
#
# Added 'Aircraft carrier' theme.
# 30 / 442   ------    6.787330316742081 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 7 columns):
# question         337 non-null object
# id               337 non-null object
# is_impossible    337 non-null bool
# context          337 non-null object
# answer_start     337 non-null int64
# answer_text      337 non-null object
# title            337 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.2+ KB
# None
#
# Added 'Federal Aviation Administration' theme.
# 31 / 442   ------    7.013574660633484 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 7 columns):
# question         109 non-null object
# id               109 non-null object
# is_impossible    109 non-null bool
# context          109 non-null object
# answer_start     109 non-null int64
# answer_text      109 non-null object
# title            109 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 5.3+ KB
# None
#
# Added 'Lancashire' theme.
# 32 / 442   ------    7.239819004524888 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 7 columns):
# question         195 non-null object
# id               195 non-null object
# is_impossible    195 non-null bool
# context          195 non-null object
# answer_start     195 non-null int64
# answer_text      195 non-null object
# title            195 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.4+ KB
# None
#
# Added 'Mesozoic' theme.
# 33 / 442   ------    7.46606334841629 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
# question         153 non-null object
# id               153 non-null object
# is_impossible    153 non-null bool
# context          153 non-null object
# answer_start     153 non-null int64
# answer_text      153 non-null object
# title            153 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 7.4+ KB
# None
#
# Added 'Videoconferencing' theme.
# 34 / 442   ------    7.6923076923076925 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 7 columns):
# question         206 non-null object
# id               206 non-null object
# is_impossible    206 non-null bool
# context          206 non-null object
# answer_start     206 non-null int64
# answer_text      206 non-null object
# title            206 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.9+ KB
# None
# Added 'Gregorian calendar' theme.
# 35 / 442   ------    7.918552036199094 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
# question         210 non-null object
# id               210 non-null object
# is_impossible    210 non-null bool
# context          210 non-null object
# answer_start     210 non-null int64
# answer_text      210 non-null object
# title            210 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.1+ KB
# None
#
# Added 'Dog' theme.
# 36 / 442   ------    8.144796380090497 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 7 columns):
# question         392 non-null object
# id               392 non-null object
# is_impossible    392 non-null bool
# context          392 non-null object
# answer_start     392 non-null int64
# answer_text      392 non-null object
# title            392 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.8+ KB
# None
#
# Added 'Xbox 360' theme.
# 37 / 442   ------    8.3710407239819 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 7 columns):
# question         256 non-null object
# id               256 non-null object
# is_impossible    256 non-null bool
# context          256 non-null object
# answer_start     256 non-null int64
# answer_text      256 non-null object
# title            256 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.3+ KB
# None
#
# Added 'Military history of the United States' theme.
# 38 / 442   ------    8.597285067873303 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 7 columns):
# question         414 non-null object
# id               414 non-null object
# is_impossible    414 non-null bool
# context          414 non-null object
# answer_start     414 non-null int64
# answer_text      414 non-null object
# title            414 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 19.9+ KB
# None
#
# Added 'Hard rock' theme.
# 39 / 442   ------    8.823529411764707 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
# question         249 non-null object
# id               249 non-null object
# is_impossible    249 non-null bool
# context          249 non-null object
# answer_start     249 non-null int64
# answer_text      249 non-null object
# title            249 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.0+ KB
# None
#
# Added 'Great Plains' theme.
# 40 / 442   ------    9.049773755656108 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
# question         108 non-null object
# id               108 non-null object
# is_impossible    108 non-null bool
# context          108 non-null object
# answer_start     108 non-null int64
# answer_text      108 non-null object
# title            108 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 5.2+ KB
# None
#
# Added 'Infrared' theme.
# 41 / 442   ------    9.276018099547512 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 7 columns):
# question         183 non-null object
# id               183 non-null object
# is_impossible    183 non-null bool
# context          183 non-null object
# answer_start     183 non-null int64
# answer_text      183 non-null object
# title            183 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 8.8+ KB
# None
#
# Added 'Biodiversity' theme.
# 42 / 442   ------    9.502262443438914 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 7 columns):
# question         302 non-null object
# id               302 non-null object
# is_impossible    302 non-null bool
# context          302 non-null object
# answer_start     302 non-null int64
# answer_text      302 non-null object
# title            302 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.5+ KB
# None
#
# Added 'ASCII' theme.
# 43 / 442   ------    9.728506787330318 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 7 columns):
# question         237 non-null object
# id               237 non-null object
# is_impossible    237 non-null bool
# context          237 non-null object
# answer_start     237 non-null int64
# answer_text      237 non-null object
# title            237 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.4+ KB
# None
#
# Added 'Digestion' theme.
# 44 / 442   ------    9.95475113122172 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 7 columns):
# question         85 non-null object
# id               85 non-null object
# is_impossible    85 non-null bool
# context          85 non-null object
# answer_start     85 non-null int64
# answer_text      85 non-null object
# title            85 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 4.1+ KB
# None
#
# Added 'Gymnastics' theme.
# 45 / 442   ------    10.180995475113122 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 7 columns):
# question         220 non-null object
# id               220 non-null object
# is_impossible    220 non-null bool
# context          220 non-null object
# answer_start     220 non-null int64
# answer_text      220 non-null object
# title            220 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.6+ KB
# None
#
# Added 'FC Barcelona' theme.
# 46 / 442   ------    10.407239819004525 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
# question         249 non-null object
# id               249 non-null object
# is_impossible    249 non-null bool
# context          249 non-null object
# answer_start     249 non-null int64
# answer_text      249 non-null object
# title            249 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.0+ KB
# None
#
# Added '2008 Summer Olympics torch relay' theme.
# 47 / 442   ------    10.633484162895927 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
# question         500 non-null object
# id               500 non-null object
# is_impossible    500 non-null bool
# context          500 non-null object
# answer_start     500 non-null int64
# answer_text      500 non-null object
# title            500 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 24.0+ KB
# None
#
# Added 'Federal Bureau of Investigation' theme.
# 48 / 442   ------    10.85972850678733 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 7 columns):
# question         441 non-null object
# id               441 non-null object
# is_impossible    441 non-null bool
# context          441 non-null object
# answer_start     441 non-null int64
# answer_text      441 non-null object
# title            441 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 21.2+ KB
# None
#
# Added 'Mary (mother of Jesus)' theme.
# 49 / 442   ------    11.085972850678733 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
# question         366 non-null object
# id               366 non-null object
# is_impossible    366 non-null bool
# context          366 non-null object
# answer_start     366 non-null int64
# answer_text      366 non-null object
# title            366 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.6+ KB
# None
#
# Added 'Melbourne' theme.
# 50 / 442   ------    11.312217194570136 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
# question         310 non-null object
# id               310 non-null object
# is_impossible    310 non-null bool
# context          310 non-null object
# answer_start     310 non-null int64
# answer_text      310 non-null object
# title            310 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.9+ KB
# None
#
# Added 'John, King of England' theme.
# 51 / 442   ------    11.538461538461538 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
# question         250 non-null object
# id               250 non-null object
# is_impossible    250 non-null bool
# context          250 non-null object
# answer_start     250 non-null int64
# answer_text      250 non-null object
# title            250 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.0+ KB
# None
# Added 'Macintosh' theme.
# 52 / 442   ------    11.76470588235294 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 7 columns):
# question         487 non-null object
# id               487 non-null object
# is_impossible    487 non-null bool
# context          487 non-null object
# answer_start     487 non-null int64
# answer_text      487 non-null object
# title            487 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 23.4+ KB
# None
#
# Added 'Anti-aircraft warfare' theme.
# 53 / 442   ------    11.990950226244344 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 7 columns):
# question         340 non-null object
# id               340 non-null object
# is_impossible    340 non-null bool
# context          340 non-null object
# answer_start     340 non-null int64
# answer_text      340 non-null object
# title            340 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.3+ KB
# None
#
# Added 'Sanskrit' theme.
# 54 / 442   ------    12.217194570135746 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 7 columns):
# question         275 non-null object
# id               275 non-null object
# is_impossible    275 non-null bool
# context          275 non-null object
# answer_start     275 non-null int64
# answer_text      275 non-null object
# title            275 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.2+ KB
# None
#
# Added 'Valencia' theme.
# 55 / 442   ------    12.44343891402715 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
# question         250 non-null object
# id               250 non-null object
# is_impossible    250 non-null bool
# context          250 non-null object
# answer_start     250 non-null int64
# answer_text      250 non-null object
# title            250 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.0+ KB
# None
#
# Added 'General Electric' theme.
# 56 / 442   ------    12.669683257918551 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
# question         158 non-null object
# id               158 non-null object
# is_impossible    158 non-null bool
# context          158 non-null object
# answer_start     158 non-null int64
# answer_text      158 non-null object
# title            158 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 7.6+ KB
# None
#
# Added 'United States Army' theme.
# 57 / 442   ------    12.895927601809957 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 7 columns):
# question         296 non-null object
# id               296 non-null object
# is_impossible    296 non-null bool
# context          296 non-null object
# answer_start     296 non-null int64
# answer_text      296 non-null object
# title            296 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.2+ KB
# None
#
# Added 'Genome' theme.
# 58 / 442   ------    13.122171945701359 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 7 columns):
# question         201 non-null object
# id               201 non-null object
# is_impossible    201 non-null bool
# context          201 non-null object
# answer_start     201 non-null int64
# answer_text      201 non-null object
# title            201 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.7+ KB
# None
#
# Added 'Franco-Prussian War' theme.
# 59 / 442   ------    13.34841628959276 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 7 columns):
# question         287 non-null object
# id               287 non-null object
# is_impossible    287 non-null bool
# context          287 non-null object
# answer_start     287 non-null int64
# answer_text      287 non-null object
# title            287 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.8+ KB
# None
#
# Added 'Adolescence' theme.
# 60 / 442   ------    13.574660633484163 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 7 columns):
# question         320 non-null object
# id               320 non-null object
# is_impossible    320 non-null bool
# context          320 non-null object
# answer_start     320 non-null int64
# answer_text      320 non-null object
# title            320 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.4+ KB
# None
#
# Added 'Antarctica' theme.
# 61 / 442   ------    13.800904977375566 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 7 columns):
# question         525 non-null object
# id               525 non-null object
# is_impossible    525 non-null bool
# context          525 non-null object
# answer_start     525 non-null int64
# answer_text      525 non-null object
# title            525 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 25.2+ KB
# None
#
# Added 'Eritrea' theme.
# 62 / 442   ------    14.027149321266968 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 7 columns):
# question         386 non-null object
# id               386 non-null object
# is_impossible    386 non-null bool
# context          386 non-null object
# answer_start     386 non-null int64
# answer_text      386 non-null object
# title            386 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.5+ KB
# None
#
# Added 'Uranium' theme.
# 63 / 442   ------    14.25339366515837 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 7 columns):
# question         385 non-null object
# id               385 non-null object
# is_impossible    385 non-null bool
# context          385 non-null object
# answer_start     385 non-null int64
# answer_text      385 non-null object
# title            385 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.5+ KB
# None
#
# Added 'Order of the British Empire' theme.
# 64 / 442   ------    14.479638009049776 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 7 columns):
# question         63 non-null object
# id               63 non-null object
# is_impossible    63 non-null bool
# context          63 non-null object
# answer_start     63 non-null int64
# answer_text      63 non-null object
# title            63 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 3.1+ KB
# None
#
# Added 'Circadian rhythm' theme.
# 65 / 442   ------    14.705882352941178 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 7 columns):
# question         202 non-null object
# id               202 non-null object
# is_impossible    202 non-null bool
# context          202 non-null object
# answer_start     202 non-null int64
# answer_text      202 non-null object
# title            202 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.7+ KB
# None
#
# Added 'Elizabeth II' theme.
# 66 / 442   ------    14.93212669683258 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 7 columns):
# question         431 non-null object
# id               431 non-null object
# is_impossible    431 non-null bool
# context          431 non-null object
# answer_start     431 non-null int64
# answer_text      431 non-null object
# title            431 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.7+ KB
# None
#
# Added 'Sexual orientation' theme.
# 67 / 442   ------    15.158371040723981 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 7 columns):
# question         292 non-null object
# id               292 non-null object
# is_impossible    292 non-null bool
# context          292 non-null object
# answer_start     292 non-null int64
# answer_text      292 non-null object
# title            292 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.1+ KB
# None
#
# Added 'Dell' theme.
# 68 / 442   ------    15.384615384615385 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 7 columns):
# question         424 non-null object
# id               424 non-null object
# is_impossible    424 non-null bool
# context          424 non-null object
# answer_start     424 non-null int64
# answer_text      424 non-null object
# title            424 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.4+ KB
# None
#
# Added 'Comprehensive school' theme.
# 69 / 442   ------    15.610859728506787 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
# question         198 non-null object
# id               198 non-null object
# is_impossible    198 non-null bool
# context          198 non-null object
# answer_start     198 non-null int64
# answer_text      198 non-null object
# title            198 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.6+ KB
# None
#
# Added 'Capital punishment in the United States' theme.
# 70 / 442   ------    15.837104072398189 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 7 columns):
# question         422 non-null object
# id               422 non-null object
# is_impossible    422 non-null bool
# context          422 non-null object
# answer_start     422 non-null int64
# answer_text      422 non-null object
# title            422 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.3+ KB
# None
#
# Added 'Age of Enlightenment' theme.
# 71 / 442   ------    16.063348416289593 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 7 columns):
# question         347 non-null object
# id               347 non-null object
# is_impossible    347 non-null bool
# context          347 non-null object
# answer_start     347 non-null int64
# answer_text      347 non-null object
# title            347 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.7+ KB
# None
#
# Added 'Nintendo Entertainment System' theme.
# 72 / 442   ------    16.289592760180994 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 7 columns):
# question         383 non-null object
# id               383 non-null object
# is_impossible    383 non-null bool
# context          383 non-null object
# answer_start     383 non-null int64
# answer_text      383 non-null object
# title            383 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.4+ KB
# None
#
# Added 'Athanasius of Alexandria' theme.
# 73 / 442   ------    16.515837104072396 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 7 columns):
# question         377 non-null object
# id               377 non-null object
# is_impossible    377 non-null bool
# context          377 non-null object
# answer_start     377 non-null int64
# answer_text      377 non-null object
# title            377 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.1+ KB
# None
#
# Added 'Seattle' theme.
# 74 / 442   ------    16.7420814479638 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 7 columns):
# question         260 non-null object
# id               260 non-null object
# is_impossible    260 non-null bool
# context          260 non-null object
# answer_start     260 non-null int64
# answer_text      260 non-null object
# title            260 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.5+ KB
# None
#
# Added 'Memory' theme.
# 75 / 442   ------    16.968325791855204 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 7 columns):
# question         292 non-null object
# id               292 non-null object
# is_impossible    292 non-null bool
# context          292 non-null object
# answer_start     292 non-null int64
# answer_text      292 non-null object
# title            292 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.1+ KB
# None
#
# Added 'Multiracial American' theme.
# 76 / 442   ------    17.194570135746606 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 7 columns):
# question         481 non-null object
# id               481 non-null object
# is_impossible    481 non-null bool
# context          481 non-null object
# answer_start     481 non-null int64
# answer_text      481 non-null object
# title            481 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 23.1+ KB
# None
#
# Added 'Ashkenazi Jews' theme.
# 77 / 442   ------    17.420814479638008 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
# question         190 non-null object
# id               190 non-null object
# is_impossible    190 non-null bool
# context          190 non-null object
# answer_start     190 non-null int64
# answer_text      190 non-null object
# title            190 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.2+ KB
# None
#
# Added 'Pharmaceutical industry' theme.
# 78 / 442   ------    17.647058823529413 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 7 columns):
# question         586 non-null object
# id               586 non-null object
# is_impossible    586 non-null bool
# context          586 non-null object
# answer_start     586 non-null int64
# answer_text      586 non-null object
# title            586 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 28.1+ KB
# None
#
# Added 'Umayyad Caliphate' theme.
# 79 / 442   ------    17.873303167420815 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 7 columns):
# question         318 non-null object
# id               318 non-null object
# is_impossible    318 non-null bool
# context          318 non-null object
# answer_start     318 non-null int64
# answer_text      318 non-null object
# title            318 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.3+ KB
# None
#
# Added 'Republic of the Congo' theme.
# 80 / 442   ------    18.099547511312217 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 7 columns):
# question         338 non-null object
# id               338 non-null object
# is_impossible    338 non-null bool
# context          338 non-null object
# answer_start     338 non-null int64
# answer_text      338 non-null object
# title            338 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.3+ KB
# None
#
# Added 'Asphalt' theme.
# 81 / 442   ------    18.32579185520362 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 7 columns):
# question         352 non-null object
# id               352 non-null object
# is_impossible    352 non-null bool
# context          352 non-null object
# answer_start     352 non-null int64
# answer_text      352 non-null object
# title            352 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.9+ KB
# None
#
# Added 'Queen Victoria' theme.
# 82 / 442   ------    18.552036199095024 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 7 columns):
# question         883 non-null object
# id               883 non-null object
# is_impossible    883 non-null bool
# context          883 non-null object
# answer_start     883 non-null int64
# answer_text      883 non-null object
# title            883 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 42.3+ KB
# None
#
# Added 'Freemasonry' theme.
# 83 / 442   ------    18.778280542986426 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 7 columns):
# question         444 non-null object
# id               444 non-null object
# is_impossible    444 non-null bool
# context          444 non-null object
# answer_start     444 non-null int64
# answer_text      444 non-null object
# title            444 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 21.3+ KB
# None
#
# Added 'Israel' theme.
# 84 / 442   ------    19.004524886877828 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 7 columns):
# question         297 non-null object
# id               297 non-null object
# is_impossible    297 non-null bool
# context          297 non-null object
# answer_start     297 non-null int64
# answer_text      297 non-null object
# title            297 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.3+ KB
# None
#
# Added 'Hellenistic period' theme.
# 85 / 442   ------    19.230769230769234 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 7 columns):
# question         440 non-null object
# id               440 non-null object
# is_impossible    440 non-null bool
# context          440 non-null object
# answer_start     440 non-null int64
# answer_text      440 non-null object
# title            440 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 21.1+ KB
# None
# Added 'Bill %26 Melinda Gates Foundation' theme.
# 86 / 442   ------    19.457013574660635 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 7 columns):
# question         185 non-null object
# id               185 non-null object
# is_impossible    185 non-null bool
# context          185 non-null object
# answer_start     185 non-null int64
# answer_text      185 non-null object
# title            185 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 8.9+ KB
# None
#
# Added 'Montevideo' theme.
# 87 / 442   ------    19.683257918552037 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 7 columns):
# question         247 non-null object
# id               247 non-null object
# is_impossible    247 non-null bool
# context          247 non-null object
# answer_start     247 non-null int64
# answer_text      247 non-null object
# title            247 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.9+ KB
# None
#
# Added 'Poultry' theme.
# 88 / 442   ------    19.90950226244344 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
# question         310 non-null object
# id               310 non-null object
# is_impossible    310 non-null bool
# context          310 non-null object
# answer_start     310 non-null int64
# answer_text      310 non-null object
# title            310 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.9+ KB
# None
#
# Added 'Dutch language' theme.
# 89 / 442   ------    20.13574660633484 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
# question         250 non-null object
# id               250 non-null object
# is_impossible    250 non-null bool
# context          250 non-null object
# answer_start     250 non-null int64
# answer_text      250 non-null object
# title            250 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.0+ KB
# None
#
# Added 'Buckingham Palace' theme.
# 90 / 442   ------    20.361990950226243 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 7 columns):
# question         388 non-null object
# id               388 non-null object
# is_impossible    388 non-null bool
# context          388 non-null object
# answer_start     388 non-null int64
# answer_text      388 non-null object
# title            388 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.6+ KB
# None
#
# Added 'Prime minister' theme.
# 91 / 442   ------    20.588235294117645 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
# question         196 non-null object
# id               196 non-null object
# is_impossible    196 non-null bool
# context          196 non-null object
# answer_start     196 non-null int64
# answer_text      196 non-null object
# title            196 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.5+ KB
# None
#
# Added 'Incandescent light bulb' theme.
# 92 / 442   ------    20.81447963800905 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 7 columns):
# question         393 non-null object
# id               393 non-null object
# is_impossible    393 non-null bool
# context          393 non-null object
# answer_start     393 non-null int64
# answer_text      393 non-null object
# title            393 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.9+ KB
# None
#
# Added 'Arsenal F.C.' theme.
# 93 / 442   ------    21.040723981900452 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 7 columns):
# question         334 non-null object
# id               334 non-null object
# is_impossible    334 non-null bool
# context          334 non-null object
# answer_start     334 non-null int64
# answer_text      334 non-null object
# title            334 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.1+ KB
# None
#
# Added 'Clothing' theme.
# 94 / 442   ------    21.266968325791854 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 7 columns):
# question         203 non-null object
# id               203 non-null object
# is_impossible    203 non-null bool
# context          203 non-null object
# answer_start     203 non-null int64
# answer_text      203 non-null object
# title            203 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.8+ KB
# None
#
# Added 'Chicago Cubs' theme.
# 95 / 442   ------    21.49321266968326 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
# question         210 non-null object
# id               210 non-null object
# is_impossible    210 non-null bool
# context          210 non-null object
# answer_start     210 non-null int64
# answer_text      210 non-null object
# title            210 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.1+ KB
# None
#
# Added 'Korean War' theme.
# 96 / 442   ------    21.71945701357466 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 7 columns):
# question         348 non-null object
# id               348 non-null object
# is_impossible    348 non-null bool
# context          348 non-null object
# answer_start     348 non-null int64
# answer_text      348 non-null object
# title            348 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 16.7+ KB
# None
#
# Added 'Copyright infringement' theme.
# 97 / 442   ------    21.945701357466064 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371 entries, 0 to 370
# Data columns (total 7 columns):
# ...
# 8                          When did Beyoncé rise to fame?
# 9          What role did Beyoncé have in Destiny's Child?
# 10      What was the first album Beyoncé released as a...
# 11          When did Beyoncé release Dangerously in Love?
# 12      How many Grammy awards did Beyoncé win for her...
# 13            What was Beyoncé's role in Destiny's Child?
# 14       What was the name of Beyoncé's first solo album?
# 15      After her second solo album, what other entert...
# 16                        Which artist did Beyonce marry?
# 17      To set the record for Grammys, how many did Be...
# 18      For what movie did Beyonce receive  her first ...
# 19      When did Beyonce take a hiatus in her career a...
# 20      Which album was darker in tone from her previo...
# 21      After what movie portraying Etta James, did Be...
# 22          When did Destiny's Child end their group act?
# 23      What was the name of Beyoncé's second solo album?
# 24          What was Beyoncé's first acting job, in 2006?
# 25                             Who is Beyoncé married to?
# 26               What is the name of Beyoncé's alter-ego?
# 27      In her music, what are some recurring elements...
# 28      Time magazine named her one of the most 100 wh...
# 29      Which magazine declared her the most dominant ...
# ...                                                   ...
# 130289  What is the primary trigger for immunological ...
# 130290  What specific hormone catalyzes these changes ...
# 130291  Which specific hormone precipitates the change...
# 130292  Adolescent immunological changes can also resu...
# 130293  Evidence suggests that receptors on B cells ma...
# 130294  The routine practice of immunology can best be...
# 130295  What are two opposing theories of early 20th c...
# 130296  Cellular immunology expressed the theory that ...
# 130297  Humoral immunology theorized that the origin o...
# 130298  Rather than cells, in humoral immunology where...
# 130299  What medical scientist first proposed the clon...
# 130300  What triggers an immune response according to ...
# 130301  In CST, what triggers a destructive immune res...
# 130302  What property of T cells caused modification o...
# 130303   When was clonal selection theory first proposed?
# 130304  What discipline can undergraduate students int...
# 130305  Immunology is a branch of what larger field of...
# 130306  The goal of an immunologist is to study what b...
# 130307  The biggest part of an immunologist's job is w...
# 130308  What two conditions apply to good immunologica...
# 130309  Most graduate schools specializing in immunolo...
# 130310  What is the name of the immunology school at M...
# 130311  AAI immunology courses include what two compon...
# 130312  What does the introductory AAI immunology cour...
# 130313  The Langone Medical Center is part of what col...
# 130314  Part 1 of the AAI introductory immunology cour...
# 130315  Part 2 of the AAI introductory immunology cour...
# 130316  What pre-requisite should enrollees in the adv...
# 130317  How long does it typically take to earn a Mast...
# 130318  What program requires an additional two years ...
#
#                               id  is_impossible  \
# 0       56be85543aeaaa14008c9063          False
# 1       56be85543aeaaa14008c9065          False
# 2       56be85543aeaaa14008c9066          False
# 3       56bf6b0f3aeaaa14008c9601          False
# 4       56bf6b0f3aeaaa14008c9602          False
# 5       56bf6b0f3aeaaa14008c9603          False
# 6       56bf6b0f3aeaaa14008c9604          False
# 7       56bf6b0f3aeaaa14008c9605          False
# 8       56d43c5f2ccc5a1400d830a9          False
# 9       56d43c5f2ccc5a1400d830aa          False
# 10      56d43c5f2ccc5a1400d830ab          False
# 11      56d43c5f2ccc5a1400d830ac          False
# 12      56d43c5f2ccc5a1400d830ad          False
# 13      56d43ce42ccc5a1400d830b4          False
# 14      56d43ce42ccc5a1400d830b5          False
# 15      56be86cf3aeaaa14008c9076          False
# 16      56be86cf3aeaaa14008c9078          False
# 17      56be86cf3aeaaa14008c9079          False
# 18      56bf6e823aeaaa14008c9627          False
# 19      56bf6e823aeaaa14008c9629          False
# 20      56bf6e823aeaaa14008c962a          False
# 21      56bf6e823aeaaa14008c962b          False
# 22      56d43da72ccc5a1400d830bd          False
# 23      56d43da72ccc5a1400d830be          False
# 24      56d43da72ccc5a1400d830bf          False
# 25      56d43da72ccc5a1400d830c0          False
# 26      56d43da72ccc5a1400d830c1          False
# 27      56be88473aeaaa14008c9080          False
# 28      56be88473aeaaa14008c9083          False
# 29      56be88473aeaaa14008c9084          False
# ...                          ...            ...
# 130289  5706e5b49e06ca38007e9205          False
# 130290  5706e5b49e06ca38007e9206          False
# 130291  5706e5b49e06ca38007e9207          False
# 130292  5706e5b49e06ca38007e9208          False
# 130293  5706e5b49e06ca38007e9209          False
# 130294  5706f5de90286e26004fc763          False
# 130295  5706f5de90286e26004fc764          False
# 130296  5706f5de90286e26004fc765          False
# 130297  5706f5de90286e26004fc766          False
# 130298  5706f5de90286e26004fc767          False
# 130299  5706f93b9e06ca38007e9267          False
# 130300  5706f93b9e06ca38007e9268          False
# 130301  5706f93b9e06ca38007e9269          False
# 130302  5706f93b9e06ca38007e926a          False
# 130303  5706f93b9e06ca38007e926b          False
# 130304  5706facf9e06ca38007e927b          False
# 130305  5706facf9e06ca38007e927c          False
# 130306  5706facf9e06ca38007e927d          False
# 130307  5706facf9e06ca38007e927e          False
# 130308  5706facf9e06ca38007e927f          False
# 130309  5706fbf590286e26004fc7a5          False
# 130310  5706fbf590286e26004fc7a6          False
# 130311  5706fbf590286e26004fc7a7          False
# 130312  5706fbf590286e26004fc7a8          False
# 130313  5706fbf590286e26004fc7a9          False
# 130314  5706fd4e90286e26004fc7af          False
# 130315  5706fd4e90286e26004fc7b0          False
# 130316  5706fd4e90286e26004fc7b1          False
# 130317  5706fd4e90286e26004fc7b2          False
# 130318  5706fd4e90286e26004fc7b3          False
#
#                                                   context  answer_start  \
# 0       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           269
# 1       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           207
# 2       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           526
# 3       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           166
# 4       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           276
# 5       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           320
# 6       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           505
# 7       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           360
# 8       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           276
# 9       Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           290
# 10      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           505
# 11      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           526
# 12      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           590
# 13      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           290
# 14      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...           505
# 15      Following the disbandment of Destiny's Child i...           207
# 16      Following the disbandment of Destiny's Child i...           369
# 17      Following the disbandment of Destiny's Child i...           565
# 18      Following the disbandment of Destiny's Child i...           260
# 19      Following the disbandment of Destiny's Child i...           586
# 20      Following the disbandment of Destiny's Child i...           180
# 21      Following the disbandment of Destiny's Child i...           406
# 22      Following the disbandment of Destiny's Child i...            48
# 23      Following the disbandment of Destiny's Child i...            95
# 24      Following the disbandment of Destiny's Child i...           260
# 25      Following the disbandment of Destiny's Child i...           369
# 26      Following the disbandment of Destiny's Child i...           466
# 27      A self-described "modern-day feminist", Beyonc...           104
# 28      A self-described "modern-day feminist", Beyonc...           935
# 29      A self-described "modern-day feminist", Beyonc...           985
# ...                                                   ...           ...
# 130289  During adolescence, the human body undergoes v...           129
# 130290  During adolescence, the human body undergoes v...           183
# 130291  During adolescence, the human body undergoes v...           232
# 130292  During adolescence, the human body undergoes v...           541
# 130293  During adolescence, the human body undergoes v...           700
# 130294  Immunology is strongly experimental in everyda...            14
# 130295  Immunology is strongly experimental in everyda...           317
# 130296  Immunology is strongly experimental in everyda...           488
# 130297  Immunology is strongly experimental in everyda...           688
# 130298  Immunology is strongly experimental in everyda...           728
# 130299  In the mid-1950s, Frank Burnet, inspired by a ...            18
# 130300  In the mid-1950s, Frank Burnet, inspired by a ...           239
# 130301  In the mid-1950s, Frank Burnet, inspired by a ...           363
# 130302  In the mid-1950s, Frank Burnet, inspired by a ...           542
# 130303  In the mid-1950s, Frank Burnet, inspired by a ...             0
# 130304  Bioscience is the overall major in which under...             0
# 130305  Bioscience is the overall major in which under...           148
# 130306  Bioscience is the overall major in which under...           319
# 130307  Bioscience is the overall major in which under...           454
# 130308  Bioscience is the overall major in which under...           346
# 130309  Most graduate immunology schools follow the AA...            44
# 130310  Most graduate immunology schools follow the AA...           281
# 130311  Most graduate immunology schools follow the AA...           541
# 130312  Most graduate immunology schools follow the AA...           625
# 130313  Most graduate immunology schools follow the AA...           322
# 130314  In addition, this Introductory Course gives st...           164
# 130315  In addition, this Introductory Course gives st...           235
# 130316  In addition, this Introductory Course gives st...           483
# 130317  In addition, this Introductory Course gives st...           640
# 130318  In addition, this Introductory Course gives st...           712
#
#                                               answer_text       title
# 0                                       in the late 1990s     Beyoncé
# 1                                     singing and dancing     Beyoncé
# 2                                                    2003     Beyoncé
# 3                                          Houston, Texas     Beyoncé
# 4                                              late 1990s     Beyoncé
# 5                                         Destiny's Child     Beyoncé
# 6                                     Dangerously in Love     Beyoncé
# 7                                          Mathew Knowles     Beyoncé
# 8                                              late 1990s     Beyoncé
# 9                                             lead singer     Beyoncé
# 10                                    Dangerously in Love     Beyoncé
# 11                                                   2003     Beyoncé
# 12                                                   five     Beyoncé
# 13                                            lead singer     Beyoncé
# 14                                    Dangerously in Love     Beyoncé
# 15                                                 acting     Beyoncé
# 16                                                  Jay Z     Beyoncé
# 17                                                    six     Beyoncé
# 18                                             Dreamgirls     Beyoncé
# 19                                                   2010     Beyoncé
# 20                                                Beyoncé     Beyoncé
# 21                                       Cadillac Records     Beyoncé
# 22                                              June 2005     Beyoncé
# 23                                                  B'Day     Beyoncé
# 24                                             Dreamgirls     Beyoncé
# 25                                                  Jay Z     Beyoncé
# 26                                           Sasha Fierce     Beyoncé
# 27                      love, relationships, and monogamy     Beyoncé
# 28                                            influential     Beyoncé
# 29                                                 Forbes     Beyoncé
# ...                                                   ...         ...
# 130289                                           hormones  Immunology
# 130290                     17-β-oestradiol (an oestrogen)  Immunology
# 130291                                       testosterone  Immunology
# 130292  increased risk in developing pubescent and pos...  Immunology
# 130293                  detect sex hormones in the system  Immunology
# 130294                              strongly experimental  Immunology
# 130295                           "cellular" and "humoral"  Immunology
# 130296                                         phagocytes  Immunology
# 130297                     soluble components (molecules)  Immunology
# 130298                            the organism’s “humors”  Immunology
# 130299                                       Frank Burnet  Immunology
# 130300                           self/nonself distinction  Immunology
# 130301  "nonself" entities (e.g., pathogens, an allogr...  Immunology
# 130302                the complex "two-signal" activation  Immunology
# 130303                                   In the mid-1950s  Immunology
# 130304                                         Bioscience  Immunology
# 130305                                         bioscience  Immunology
# 130306                                 humans and animals  Immunology
# 130307                                           research  Immunology
# 130308                  effective yet consistent research  Immunology
# 130309                                        AAI courses  Immunology
# 130310                           Icahn School of Medicine  Immunology
# 130311          Introductory Course and an Advance Course  Immunology
# 130312  gives students an overview of the basics of im...  Immunology
# 130313                                New York University  Immunology
# 130314  an introduction to the basic principles of imm...  Immunology
# 130315                 clinically-oriented lecture series  Immunology
# 130316       a background of the principles of immunology  Immunology
# 130317                                 two years of study  Immunology
# 130318                               a doctoral programme  Immunology
#
# [130319 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130319 entries, 0 to 130318
# Data columns (total 7 columns):
# question         130319 non-null object
# id               130319 non-null object
# is_impossible    130319 non-null bool
# context          130319 non-null object
# answer_start     130319 non-null int64
# answer_text      130319 non-null object
# title            130319 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 6.1+ MB
# None

# %% [markdown]
# ### Importing and Structuring the Development Set
# Having constructed a dataframe for the training set, we will now do the same for the dev set.

# %%
dev_file=pd.read_json("https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json")[["data"]].to_json("dev_file.json")
dev_file2=pd.read_json("dev_file.json", orient="split").transpose().reset_index(drop=True)
dev_file2["title"]=dev_file2.loc[:,"title"].str.replace("_"," ")
dev_themes=dev_file2["title"].values

# %%
# Creating dataframes for all themes
dev_df=pd.DataFrame()

# Looping over each theme in the JSON
for n_theme, theme in enumerate(dev_themes):
    theme_contexts=dev_file2.iloc[n_theme,0] 
    theme_df=pd.DataFrame()
    # Going over all 'contexts' (paragraphs of data) within theme
    for context in theme_contexts:
        context_df=pd.DataFrame(data=context["qas"]).loc[:,["question", "id", "is_impossible"]] 
        context_df["context"]=context["context"]
        impossible_question=context_df["is_impossible"].values #boolean array to denote if given question of context is impossible
        context_df=context_df.join(pd.DataFrame(data=answer_data(context, impossible_question)))
        theme_df=theme_df.append(context_df, ignore_index=True)
        
    theme_df["title"]=theme
    dev_df=dev_df.append(theme_df, ignore_index=True) 
       
    # Some debugging/progress prints
    print("Added '%s' theme." % theme)
    print(n_theme+1,"/",len(dev_themes), "  ------   ", (float(n_theme+1)/float(len(dev_themes)))*100, "%")
    print(theme_df.info(),"\n")
   
print(dev_df)
print(dev_df.info())
# Out:
# Added 'Normans' theme.
# 1 / 35   ------    2.857142857142857 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 7 columns):
# question         208 non-null object
# id               208 non-null object
# is_impossible    208 non-null bool
# context          208 non-null object
# answer_start     208 non-null int64
# answer_text      208 non-null object
# title            208 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.0+ KB
# None
#
# Added 'Computational complexity theory' theme.
# 2 / 35   ------    5.714285714285714 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
# question         418 non-null object
# id               418 non-null object
# is_impossible    418 non-null bool
# context          418 non-null object
# answer_start     418 non-null int64
# answer_text      418 non-null object
# title            418 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.1+ KB
# None
#
# Added 'Amazon rainforest' theme.
# 3 / 35   ------    8.571428571428571 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 7 columns):
# question         284 non-null object
# id               284 non-null object
# is_impossible    284 non-null bool
# context          284 non-null object
# answer_start     284 non-null int64
# answer_text      284 non-null object
# title            284 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.7+ KB
# None
#
# Added 'Ctenophora' theme.
# 4 / 35   ------    11.428571428571429 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 7 columns):
# question         325 non-null object
# id               325 non-null object
# is_impossible    325 non-null bool
# context          325 non-null object
# answer_start     325 non-null int64
# answer_text      325 non-null object
# title            325 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.6+ KB
# None
#
# Added 'Fresno, California' theme.
# 5 / 35   ------    14.285714285714285 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 7 columns):
# question         275 non-null object
# id               275 non-null object
# is_impossible    275 non-null bool
# context          275 non-null object
# answer_start     275 non-null int64
# answer_text      275 non-null object
# title            275 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 13.2+ KB
# None
#
# Added 'Packet switching' theme.
# 6 / 35   ------    17.142857142857142 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 7 columns):
# question         373 non-null object
# id               373 non-null object
# is_impossible    373 non-null bool
# context          373 non-null object
# answer_start     373 non-null int64
# answer_text      373 non-null object
# title            373 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.9+ KB
# None
#
# Added 'Black Death' theme.
# 7 / 35   ------    20.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 7 columns):
# question         219 non-null object
# id               219 non-null object
# is_impossible    219 non-null bool
# context          219 non-null object
# answer_start     219 non-null int64
# answer_text      219 non-null object
# title            219 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.6+ KB
# None
#
# Added 'Geology' theme.
# 8 / 35   ------    22.857142857142858 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 7 columns):
# question         362 non-null object
# id               362 non-null object
# is_impossible    362 non-null bool
# context          362 non-null object
# answer_start     362 non-null int64
# answer_text      362 non-null object
# title            362 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.4+ KB
# None
#
# Added 'Pharmacy' theme.
# 9 / 35   ------    25.71428571428571 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# question         244 non-null object
# id               244 non-null object
# is_impossible    244 non-null bool
# context          244 non-null object
# answer_start     244 non-null int64
# answer_text      244 non-null object
# title            244 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.8+ KB
# None
#
# Added 'Civil disobedience' theme.
# 10 / 35   ------    28.57142857142857 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 7 columns):
# question         327 non-null object
# id               327 non-null object
# is_impossible    327 non-null bool
# context          327 non-null object
# answer_start     327 non-null int64
# answer_text      327 non-null object
# title            327 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.7+ KB
# None
#
# Added 'Construction' theme.
# 11 / 35   ------    31.428571428571427 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 7 columns):
# question         232 non-null object
# id               232 non-null object
# is_impossible    232 non-null bool
# context          232 non-null object
# answer_start     232 non-null int64
# answer_text      232 non-null object
# title            232 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.2+ KB
# None
#
# Added 'Private school' theme.
# 12 / 35   ------    34.285714285714285 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
# question         240 non-null object
# id               240 non-null object
# is_impossible    240 non-null bool
# context          240 non-null object
# answer_start     240 non-null int64
# answer_text      240 non-null object
# title            240 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.6+ KB
# None
#
# Added 'Southern California' theme.
# 13 / 35   ------    37.142857142857146 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 7 columns):
# question         324 non-null object
# id               324 non-null object
# is_impossible    324 non-null bool
# context          324 non-null object
# answer_start     324 non-null int64
# answer_text      324 non-null object
# title            324 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 15.6+ KB
# None
#
# Added 'Harvard University' theme.
# 14 / 35   ------    40.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 7 columns):
# question         262 non-null object
# id               262 non-null object
# is_impossible    262 non-null bool
# context          262 non-null object
# answer_start     262 non-null int64
# answer_text      262 non-null object
# title            262 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.6+ KB
# None
#
# Added 'Jacksonville, Florida' theme.
# 15 / 35   ------    42.857142857142854 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 7 columns):
# question         192 non-null object
# id               192 non-null object
# is_impossible    192 non-null bool
# context          192 non-null object
# answer_start     192 non-null int64
# answer_text      192 non-null object
# title            192 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 9.3+ KB
# None
#
# Added 'Economic inequality' theme.
# 16 / 35   ------    45.714285714285715 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 7 columns):
# question         515 non-null object
# id               515 non-null object
# is_impossible    515 non-null bool
# context          515 non-null object
# answer_start     515 non-null int64
# answer_text      515 non-null object
# title            515 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 24.7+ KB
# None
#
# Added 'University of Chicago' theme.
# 17 / 35   ------    48.57142857142857 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 7 columns):
# question         356 non-null object
# id               356 non-null object
# is_impossible    356 non-null bool
# context          356 non-null object
# answer_start     356 non-null int64
# answer_text      356 non-null object
# title            356 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.1+ KB
# None
# Added 'Yuan dynasty' theme.
# 18 / 35   ------    51.42857142857142 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 7 columns):
# question         445 non-null object
# id               445 non-null object
# is_impossible    445 non-null bool
# context          445 non-null object
# answer_start     445 non-null int64
# answer_text      445 non-null object
# title            445 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 21.4+ KB
# None
#
# Added 'Immune system' theme.
# 19 / 35   ------    54.285714285714285 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 7 columns):
# question         458 non-null object
# id               458 non-null object
# is_impossible    458 non-null bool
# context          458 non-null object
# answer_start     458 non-null int64
# answer_text      458 non-null object
# title            458 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 22.0+ KB
# None
#
# Added 'Intergovernmental Panel on Climate Change' theme.
# 20 / 35   ------    57.14285714285714 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 7 columns):
# question         222 non-null object
# id               222 non-null object
# is_impossible    222 non-null bool
# context          222 non-null object
# answer_start     222 non-null int64
# answer_text      222 non-null object
# title            222 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.7+ KB
# None
#
# Added 'Prime number' theme.
# 21 / 35   ------    60.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 7 columns):
# question         308 non-null object
# id               308 non-null object
# is_impossible    308 non-null bool
# context          308 non-null object
# answer_start     308 non-null int64
# answer_text      308 non-null object
# title            308 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 14.8+ KB
# None
#
# Added 'Rhine' theme.
# 22 / 35   ------    62.857142857142854 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 7 columns):
# question         498 non-null object
# id               498 non-null object
# is_impossible    498 non-null bool
# context          498 non-null object
# answer_start     498 non-null int64
# answer_text      498 non-null object
# title            498 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 23.9+ KB
# None
#
# Added 'Scottish Parliament' theme.
# 23 / 35   ------    65.71428571428571 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 7 columns):
# question         357 non-null object
# id               357 non-null object
# is_impossible    357 non-null bool
# context          357 non-null object
# answer_start     357 non-null int64
# answer_text      357 non-null object
# title            357 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.2+ KB
# None
#
# Added 'Sky (United Kingdom)' theme.
# 24 / 35   ------    68.57142857142857 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 7 columns):
# question         210 non-null object
# id               210 non-null object
# is_impossible    210 non-null bool
# context          210 non-null object
# answer_start     210 non-null int64
# answer_text      210 non-null object
# title            210 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 10.1+ KB
# None
#
# Added 'Islamism' theme.
# 25 / 35   ------    71.42857142857143 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 7 columns):
# question         384 non-null object
# id               384 non-null object
# is_impossible    384 non-null bool
# context          384 non-null object
# answer_start     384 non-null int64
# answer_text      384 non-null object
# title            384 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.5+ KB
# None
#
# Added 'Imperialism' theme.
# 26 / 35   ------    74.28571428571429 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 7 columns):
# question         364 non-null object
# id               364 non-null object
# is_impossible    364 non-null bool
# context          364 non-null object
# answer_start     364 non-null int64
# answer_text      364 non-null object
# title            364 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 17.5+ KB
# None
#
# Added 'Warsaw' theme.
# 27 / 35   ------    77.14285714285715 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 7 columns):
# question         486 non-null object
# id               486 non-null object
# is_impossible    486 non-null bool
# context          486 non-null object
# answer_start     486 non-null int64
# answer_text      486 non-null object
# title            486 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 23.3+ KB
# None
#
# Added 'French and Indian War' theme.
# 28 / 35   ------    80.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 7 columns):
# question         402 non-null object
# id               402 non-null object
# is_impossible    402 non-null bool
# context          402 non-null object
# answer_start     402 non-null int64
# answer_text      402 non-null object
# title            402 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 19.3+ KB
# None
#
# Added 'Force' theme.
# 29 / 35   ------    82.85714285714286 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 7 columns):
# question         377 non-null object
# id               377 non-null object
# is_impossible    377 non-null bool
# context          377 non-null object
# answer_start     377 non-null int64
# answer_text      377 non-null object
# title            377 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 18.1+ KB
# None
#
# Added 'Victoria (Australia)' theme.
# 30 / 35   ------    85.71428571428571 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 7 columns):
# question         247 non-null object
# id               247 non-null object
# is_impossible    247 non-null bool
# context          247 non-null object
# answer_start     247 non-null int64
# answer_text      247 non-null object
# title            247 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 11.9+ KB
# None
#
# Added 'Huguenot' theme.
# 31 / 35   ------    88.57142857142857 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 7 columns):
# question         424 non-null object
# id               424 non-null object
# is_impossible    424 non-null bool
# context          424 non-null object
# answer_start     424 non-null int64
# answer_text      424 non-null object
# title            424 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.4+ KB
# None
#
# Added 'Steam engine' theme.
# 32 / 35   ------    91.42857142857143 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 7 columns):
# question         444 non-null object
# id               444 non-null object
# is_impossible    444 non-null bool
# context          444 non-null object
# answer_start     444 non-null int64
# answer_text      444 non-null object
# title            444 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 21.3+ KB
# None
#
# Added 'Oxygen' theme.
# 33 / 35   ------    94.28571428571428 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 7 columns):
# question         415 non-null object
# id               415 non-null object
# is_impossible    415 non-null bool
# context          415 non-null object
# answer_start     400 non-null float64
# answer_text      400 non-null object
# title            415 non-null object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 19.9+ KB
# None
#
# Added '1973 oil crisis' theme.
# 34 / 35   ------    97.14285714285714 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 7 columns):
# question         255 non-null object
# id               255 non-null object
# is_impossible    255 non-null bool
# context          255 non-null object
# answer_start     255 non-null int64
# answer_text      255 non-null object
# title            255 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 12.3+ KB
# None
# Added 'European Union law' theme.
# 35 / 35   ------    100.0 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 7 columns):
# question         421 non-null object
# id               421 non-null object
# is_impossible    421 non-null bool
# context          421 non-null object
# answer_start     421 non-null int64
# answer_text      421 non-null object
# title            421 non-null object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 20.2+ KB
# None
#
#                                                 question  \
# 0                   In what country is Normandy located?
# 1                     When were the Normans in Normandy?
# 2          From which countries did the Norse originate?
# 3                              Who was the Norse leader?
# 4      What century did the Normans first gain their ...
# 5      Who gave their name to Normandy in the 1000's ...
# 6                            What is France a region of?
# 7              Who did King Charles III swear fealty to?
# 8                 When did the Frankish identity emerge?
# 9            Who was the duke in the battle of Hastings?
# 10                       Who ruled the duchy of Normandy
# 11                        What religion were the Normans
# 12     What type of major impact did the Norman dynas...
# 13             Who was famed for their Christian spirit?
# 14                    Who assimilted the Roman language?
# 15                    Who ruled the country of Normandy?
# 16     What principality did William the conquerer fo...
# 17      What is the original meaning of the word Norman?
# 18     When was the Latin version of the word Norman ...
# 19     What name comes from the English words Normans...
# 20     When was the French version of the word Norman...
# 21               When was the Duchy of Normandy founded?
# 22     Who did Rollo sign the treaty of Saint-Clair-s...
# 23               What river originally bounded the Duchy
# 24     when did Nors encampments ivolve into destruct...
# 25       What treaty was established in the 9th century?
# 26     Who established a treaty with King Charles the...
# 27     What did the French promises to protect Rollo ...
# 28     Who upon arriving gave the original viking set...
# 29           When did Rollo begin to arrive in Normandy?
# ...                                                  ...
# 11843  Who does not have the right to set up an enter...
# 11844  Who did the Court of Justice say could help th...
# 11845  What did the Grand Chamber of the Court of Jus...
# 11846  In which year did a toxic waste spill from a E...
# 11847  At the time, countries such as Spain didn't ha...
# 11848  When did the Court of Justice rule that the Co...
# 11849  When was the competence for the Union to creat...
# 11850  What year did a toxic waste spill from an Amer...
# 11851  What did countries such as Spain have a crime ...
# 11852  What did Franco Frattini, the Justice, Freedom...
# 11853  When did the Court of Justice deny that the Co...
# 11854  The freedom to provide services under TFEU art...
# 11855  Why was the Dutch lawyer who moved to Belgium ...
# 11856  What did the Court of Justice reason were cont...
# 11857  What did the Dutch health authorities regard a...
# 11858         Who does the TFEU article 56 not apply to?
# 11859  Why could a Dutch lawyer who moved to Belgium ...
# 11860  What does not fall outside the scope of articl...
# 11861  What did Dutch health authorities regard as ne...
# 11862  What should fall under article 56 according to...
# 11863  Which newspaper's parent company could not eva...
# 11864  How much capital did UK law require to start a...
# 11865  How much capital did Danish law require to sta...
# 11866  What could justify restrictions on freedom of ...
# 11867  In which case did the Court of Justice hold th...
# 11868  Who riled that member stated could not restric...
# 11869  Who could evade taxes by shifting its resident...
# 11870        Why did the UK have to justify its actions?
# 11871  How much capital did the UK not require to sta...
# 11872  How much did Denmark not require to start a co...
#
#                              id  is_impossible  \
# 0      56ddde6b9a695914005b9628          False
# 1      56ddde6b9a695914005b9629          False
# 2      56ddde6b9a695914005b962a          False
# 3      56ddde6b9a695914005b962b          False
# 4      56ddde6b9a695914005b962c          False
# 5      5ad39d53604f3c001a3fe8d1           True
# 6      5ad39d53604f3c001a3fe8d2           True
# 7      5ad39d53604f3c001a3fe8d3           True
# 8      5ad39d53604f3c001a3fe8d4           True
# 9      56dddf4066d3e219004dad5f          False
# 10     56dddf4066d3e219004dad60          False
# 11     56dddf4066d3e219004dad61          False
# 12     5ad3a266604f3c001a3fea27           True
# 13     5ad3a266604f3c001a3fea28           True
# 14     5ad3a266604f3c001a3fea29           True
# 15     5ad3a266604f3c001a3fea2a           True
# 16     5ad3a266604f3c001a3fea2b           True
# 17     56dde0379a695914005b9636          False
# 18     56dde0379a695914005b9637          False
# 19     5ad3ab70604f3c001a3feb89           True
# 20     5ad3ab70604f3c001a3feb8a           True
# 21     56dde0ba66d3e219004dad75          False
# 22     56dde0ba66d3e219004dad76          False
# 23     56dde0ba66d3e219004dad77          False
# 24     5ad3ad61604f3c001a3fec0d           True
# 25     5ad3ad61604f3c001a3fec0e           True
# 26     5ad3ad61604f3c001a3fec0f           True
# 27     5ad3ad61604f3c001a3fec10           True
# 28     56dde1d966d3e219004dad8d          False
# 29     5ad3ae14604f3c001a3fec39           True
# ...                         ...            ...
# 11843  5ad15a11645df0001a2d1858           True
# 11844  5ad15a11645df0001a2d1859           True
# 11845  5ad15a11645df0001a2d185a           True
# 11846  5726c19add62a815002e8f8a          False
# 11847  5726c19add62a815002e8f8b          False
# 11848  5726c19add62a815002e8f8c          False
# 11849  5726c19add62a815002e8f8d          False
# 11850  5ad15d77645df0001a2d18c0           True
# 11851  5ad15d77645df0001a2d18c1           True
# 11852  5ad15d77645df0001a2d18c2           True
# 11853  5ad15d77645df0001a2d18c3           True
# 11854  5726c3da708984140094d0d9          False
# 11855  5726c3da708984140094d0da          False
# 11856  5726c3da708984140094d0db          False
# 11857  5726c3da708984140094d0dc          False
# 11858  5ad15c52645df0001a2d18ac           True
# 11859  5ad15c52645df0001a2d18ad           True
# 11860  5ad15c52645df0001a2d18ae           True
# 11861  5ad15c52645df0001a2d18af           True
# 11862  5ad15c52645df0001a2d18b0           True
# 11863  5726c5a9f1498d1400e8eac4          False
# 11864  5726c5a9f1498d1400e8eac5          False
# 11865  5726c5a9f1498d1400e8eac6          False
# 11866  5726c5a9f1498d1400e8eac7          False
# 11867  5726c5a9f1498d1400e8eac8          False
# 11868  5ad15b19645df0001a2d187e           True
# 11869  5ad15b19645df0001a2d187f           True
# 11870  5ad15b19645df0001a2d1880           True
# 11871  5ad15b19645df0001a2d1881           True
# 11872  5ad15b19645df0001a2d1882           True
#
#                                                  context  answer_start  \
# 0      The Normans (Norman: Nourmands; French: Norman...         159.0
# 1      The Normans (Norman: Nourmands; French: Norman...          94.0
# 2      The Normans (Norman: Nourmands; French: Norman...         256.0
# 3      The Normans (Norman: Nourmands; French: Norman...         308.0
# 4      The Normans (Norman: Nourmands; French: Norman...         671.0
# 5      The Normans (Norman: Nourmands; French: Norman...           4.0
# 6      The Normans (Norman: Nourmands; French: Norman...         137.0
# 7      The Normans (Norman: Nourmands; French: Norman...         308.0
# 8      The Normans (Norman: Nourmands; French: Norman...         671.0
# 9      The Norman dynasty had a major political, cult...        1022.0
# 10     The Norman dynasty had a major political, cult...         573.0
# 11     The Norman dynasty had a major political, cult...         230.0
# 12     The Norman dynasty had a major political, cult...          31.0
# 13     The Norman dynasty had a major political, cult...         118.0
# 14     The Norman dynasty had a major political, cult...         118.0
# 15     The Norman dynasty had a major political, cult...         573.0
# 16     The Norman dynasty had a major political, cult...        1295.0
# 17     The English name "Normans" comes from the Fren...         341.0
# 18     The English name "Normans" comes from the Fren...         309.0
# 19     The English name "Normans" comes from the Fren...          17.0
# 20     The English name "Normans" comes from the Fren...         309.0
# 21     In the course of the 10th century, the initial...         244.0
# 22     In the course of the 10th century, the initial...         324.0
# 23     In the course of the 10th century, the initial...         711.0
# 24     In the course of the 10th century, the initial...          21.0
# 25     In the course of the 10th century, the initial...         285.0
# 26     In the course of the 10th century, the initial...         384.0
# 27     In the course of the 10th century, the initial...         593.0
# 28     Before Rollo's arrival, its populations did no...           7.0
# 29     Before Rollo's arrival, its populations did no...         174.0
# ...                                                  ...           ...
# 11843  As well as creating rights for "workers" who g...         991.0
# 11844  As well as creating rights for "workers" who g...        1232.0
# 11845  As well as creating rights for "workers" who g...        2020.0
# 11846  In 2006, a toxic waste spill off the coast of ...           3.0
# 11847  In 2006, a toxic waste spill off the coast of ...         334.0
# 11848  In 2006, a toxic waste spill off the coast of ...        1024.0
# 11849  In 2006, a toxic waste spill off the coast of ...         552.0
# 11850  In 2006, a toxic waste spill off the coast of ...           3.0
# 11851  In 2006, a toxic waste spill off the coast of ...         334.0
# 11852  In 2006, a toxic waste spill off the coast of ...         451.0
# 11853  In 2006, a toxic waste spill off the coast of ...        1024.0
# 11854  The "freedom to provide services" under TFEU a...          64.0
# 11855  The "freedom to provide services" under TFEU a...         369.0
# 11856  The "freedom to provide services" under TFEU a...        2318.0
# 11857  The "freedom to provide services" under TFEU a...        1124.0
# 11858  The "freedom to provide services" under TFEU a...          64.0
# 11859  The "freedom to provide services" under TFEU a...         347.0
# 11860  The "freedom to provide services" under TFEU a...         751.0
# 11861  The "freedom to provide services" under TFEU a...        1128.0
# 11862  The "freedom to provide services" under TFEU a...        1279.0
# 11863  In regard to companies, the Court of Justice h...         224.0
# 11864  In regard to companies, the Court of Justice h...         703.0
# 11865  In regard to companies, the Court of Justice h...         827.0
# 11866  In regard to companies, the Court of Justice h...        1888.0
# 11867  In regard to companies, the Court of Justice h...        1583.0
# 11868  In regard to companies, the Court of Justice h...          28.0
# 11869  In regard to companies, the Court of Justice h...         228.0
# 11870  In regard to companies, the Court of Justice h...         422.0
# 11871  In regard to companies, the Court of Justice h...         703.0
# 11872  In regard to companies, the Court of Justice h...         827.0
#
#                                              answer_text               title
# 0                                                 France             Normans
# 1                                10th and 11th centuries             Normans
# 2                            Denmark, Iceland and Norway             Normans
# 3                                                  Rollo             Normans
# 4                                           10th century             Normans
# 5                                                Normans             Normans
# 6                                               Normandy             Normans
# 7                                                  Rollo             Normans
# 8                                           10th century             Normans
# 9                                  William the Conqueror             Normans
# 10                                             Richard I             Normans
# 11                                              Catholic             Normans
# 12                      political, cultural and military             Normans
# 13                                               Normans             Normans
# 14                                               Normans             Normans
# 15                                             Richard I             Normans
# 16                                               Antioch             Normans
# 17                                                Viking             Normans
# 18                                           9th century             Normans
# 19                                             "Normans"             Normans
# 20                                           9th century             Normans
# 21                                                   911             Normans
# 22                                      King Charles III             Normans
# 23                                                 Seine             Normans
# 24                                          10th century             Normans
# 25                        treaty of Saint-Clair-sur-Epte             Normans
# 26                                                 Rollo             Normans
# 27                            further Viking incursions.             Normans
# 28                                                 Rollo             Normans
# 29                                                  880s             Normans
# ...                                                  ...                 ...
# 11843  All people or entities that engage in economic...  European Union law
# 11844  both a member state government and a private p...  European Union law
# 11845  that this had any object or effect of limiting...  European Union law
# 11846                                               2006  European Union law
# 11847                               shipping toxic waste  European Union law
# 11848                                       October 2007  European Union law
# 11849                                               2005  European Union law
# 11850                                               2006  European Union law
# 11851                               shipping toxic waste  European Union law
# 11852         criminal sentences for "ecological crimes"  European Union law
# 11853                                       October 2007  European Union law
# 11854     to people who give services "for remuneration"  European Union law
# 11855  because Dutch law said only people established...  European Union law
# 11856                                     narcotic drugs  European Union law
# 11857                                      the treatment  European Union law
# 11858  to people who give services "for remuneration"...  European Union law
# 11859  he could not continue because Dutch law said o...  European Union law
# 11860                                secondary education  European Union law
# 11861                                          treatment  European Union law
# 11862  hospital services should not be regarded as ec...  European Union law
# 11863                                     the Daily Mail  European Union law
# 11864                                                 £1  European Union law
# 11865                               200,000 Danish krone  European Union law
# 11866  creditor protection, labour rights to particip...  European Union law
# 11867          Überseering BV v Nordic Construction GmbH  European Union law
# 11868                                   Court of Justice  European Union law
# 11869              Daily Mail newspaper's parent company  European Union law
# 11870  as rules on company seats were not yet harmonised  European Union law
# 11871                                                 £1  European Union law
# 11872                               200,000 Danish krone  European Union law
#
# [11873 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11873 entries, 0 to 11872
# Data columns (total 7 columns):
# question         11873 non-null object
# id               11873 non-null object
# is_impossible    11873 non-null bool
# context          11873 non-null object
# answer_start     11858 non-null float64
# answer_text      11858 non-null object
# title            11873 non-null object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 568.2+ KB
# None

# %% [markdown]
# ### Exporting dataframes to .csv files
# Having completed the data wrangling stages, we will now export the dataframes as .csv files ready to be imported in the next stage of the project.

# %%
train_df.to_json("C:/Users/Lukas Buteliauskas/Desktop/training_data.json")
dev_df.to_json("C:/Users/Lukas Buteliauskas/Desktop/validation_data.json")
