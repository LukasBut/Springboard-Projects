# %% [markdown]
# # Building the Machine Learning Models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import RFECV
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
plt.rcParams["figure.figsize"] = [18,10]

with open("C:/Users/Lukas Buteliauskas/Desktop/Springboard Projects/Capstone Project 1 - NBA Analytics/"
          "3. Exploratory Data Analysis/Player Data Filtered.csv", "r") as player_data_file:
    player_data_df=pd.read_csv(player_data_file)
    
player_data_df_undrafted=player_data_df[player_data_df["Draft Placing"].isnull()]
player_data_df=player_data_df[player_data_df["Draft Placing"].isnull()==False]

# %% [markdown]
# Given that undrafted players make up a sizeable amount of data, and are themselves a specific group of players, their data cannot be disregarded, but at the same time the Draft Rank cannot be reverse engineered. Hence, it makes sense to consider both groups as distinct, and attempt to build models for both seperately.

# %% [markdown]
# ### Defining the Classifier Performance Printing/Testing Functions

# %%
def performance_prints(clf, X_train, X_test, y_train, y_test, cv=5, n_test_print=20):
    print("Training performance (R^2): %.3f" % clf.score(X_train, y_train))
    print("Testing performance (R^2): %.3f" % clf.score(X_test, y_test))
    scores=cross_val_score(clf, X_train, y_train, cv=cv)
    print("R^2 cross val mean: %.3f" % (scores.mean()))
    print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
    print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

    for idx, data in enumerate(zip(y_test, y_pred)): 
        if idx<n_test_print:
            print("Actual: %.2f\t  Predicted: %.2f\tDifference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
            
def my_resid_plot(y_test, y_pred, label_name=""):
    residuals=y_test-y_pred
    plt.scatter(y_pred, residuals, color="black")
    plt.title("Residual Plot")
    plt.xlabel("Predicted "+ label_name +" Values")
    plt.ylabel("Residuals")
    plt.axhline(y=0, linewidth=3, color="black")
    plt.show()

# %% [markdown]
# ## Points per Game (PTS column) Model

# %%
X=player_data_df[["Draft Placing", "eFG%", "Age", "MP"]] # creating a dataframe of only the features selected from the EDA.
y=player_data_df["PTS"] # the value we are trying to predict (dependant variable)
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42) #splitting into train and test sets

clf_pts=LinearRegression().fit(X_train, y_train)
y_pred=clf_pts.predict(X_test)

performance_prints(clf_pts, X_train, X_test, y_train, y_test)
my_resid_plot(y_test, y_pred, label_name="PTS")
# Out:
# Training performance (R^2): 0.816
# Testing performance (R^2): 0.807
# R^2 cross val mean: 0.815
# 95% confidence interval for R^2: (0.787, 0.843)
# Mean Squared Error (MSE): 6.269
#
# Some test prints:
# Actual: 2.20	  Predicted: 2.06	Difference (absolute): 0.138
# Actual: 10.20	  Predicted: 11.53	Difference (absolute): 1.333
# Actual: 3.20	  Predicted: 4.35	Difference (absolute): 1.153
# Actual: 16.50	  Predicted: 12.78	Difference (absolute): 3.720
# Actual: 2.30	  Predicted: 2.75	Difference (absolute): 0.451
# Actual: 3.80	  Predicted: 6.54	Difference (absolute): 2.742
# Actual: 6.40	  Predicted: 13.80	Difference (absolute): 7.401
# Actual: 7.90	  Predicted: 9.62	Difference (absolute): 1.724
# Actual: 10.60	  Predicted: 11.69	Difference (absolute): 1.094
# Actual: 17.00	  Predicted: 16.88	Difference (absolute): 0.116
# Actual: 1.00	  Predicted: -0.15	Difference (absolute): 1.145
# Actual: 6.40	  Predicted: 6.61	Difference (absolute): 0.206
# Actual: 1.60	  Predicted: 2.84	Difference (absolute): 1.243
# Actual: 2.40	  Predicted: 3.19	Difference (absolute): 0.788
# Actual: 10.00	  Predicted: 8.88	Difference (absolute): 1.120
# Actual: 6.20	  Predicted: 5.59	Difference (absolute): 0.615
# Actual: 13.40	  Predicted: 14.10	Difference (absolute): 0.702
# Actual: 11.10	  Predicted: 12.62	Difference (absolute): 1.520
# Actual: 5.90	  Predicted: 6.79	Difference (absolute): 0.893
# Actual: 8.70	  Predicted: 6.61	Difference (absolute): 2.089

# %% [markdown]
# Though the R^2 is quite high, the residual plot shows us that our model is biased. That is, the values of the errors in our predicitions (residuals) are not independant of the predicted values. Furthermore there is distinct increase in the spread of the residuals as well as a U-shape. All of the prior mean that perhaps we need to transform our data to achieve a model that fits the data better. The next logical step would be include polynomial transformations of the existing features. Given the scatter plots of the independant variables against PTS, we saw at most 1 point of inflection, this means we only need to consider 2nd order polynomials. Another consideration is the curse of dimentionality that would arise if we considered 3rd order polynomial features. Let us try this approach and see if our model performs better.

# %%
y=player_data_df["PTS"]
X_poly=PolynomialFeatures(degree=2).fit_transform(X)
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_pts=LinearRegression().fit(X_train, y_train)
y_pred=clf_pts.predict(X_test)

performance_prints(clf_pts, X_train, X_test, y_train, y_test)
my_resid_plot(y_test, y_pred, label_name="PTS")
# Out:
# Training performance (R^2): 0.861
# Testing performance (R^2): 0.862
# R^2 cross val mean: 0.859
# 95% confidence interval for R^2: (0.839, 0.879)
# Mean Squared Error (MSE): 4.496
#
# Some test prints:
# Actual: 2.20	  Predicted: 2.88	Difference (absolute): 0.681
# Actual: 10.20	  Predicted: 11.05	Difference (absolute): 0.854
# Actual: 3.20	  Predicted: 3.83	Difference (absolute): 0.632
# Actual: 16.50	  Predicted: 12.73	Difference (absolute): 3.771
# Actual: 2.30	  Predicted: 2.82	Difference (absolute): 0.522
# Actual: 3.80	  Predicted: 5.05	Difference (absolute): 1.252
# Actual: 6.40	  Predicted: 13.39	Difference (absolute): 6.989
# Actual: 7.90	  Predicted: 8.41	Difference (absolute): 0.509
# Actual: 10.60	  Predicted: 11.17	Difference (absolute): 0.569
# Actual: 17.00	  Predicted: 19.70	Difference (absolute): 2.697
# Actual: 1.00	  Predicted: 1.93	Difference (absolute): 0.931
# Actual: 6.40	  Predicted: 5.52	Difference (absolute): 0.880
# Actual: 1.60	  Predicted: 2.60	Difference (absolute): 0.998
# Actual: 2.40	  Predicted: 3.20	Difference (absolute): 0.800
# Actual: 10.00	  Predicted: 7.85	Difference (absolute): 2.147
# Actual: 6.20	  Predicted: 4.73	Difference (absolute): 1.473
# Actual: 13.40	  Predicted: 14.83	Difference (absolute): 1.428
# Actual: 11.10	  Predicted: 11.66	Difference (absolute): 0.560
# Actual: 5.90	  Predicted: 5.95	Difference (absolute): 0.048
# Actual: 8.70	  Predicted: 5.63	Difference (absolute): 3.075

# %% [markdown]
# By introducing polynomial features we have succeeded in reducing bias (as demonstrated by a more random residual plot) and also reduced the MSE by ~28% from 6.27 to 4.49. Also, having computed 5-fold cross validation we can be confident in our model's ability to generalise to unseen data. We could either try to tune this model further or choose a different model altogether. Let us try and predict other statistics (AST, TRB, BLK, STL) before attempting to perfect this model.

# %%
poly_feat=PolynomialFeatures(degree=3).fit(X)
X_poly=poly_feat.transform(X)
y=player_data_df["PTS"]
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
feat_selector=RFECV(LinearRegression(), cv=5).fit(X_train, y_train)
"""for name, rank in zip(poly_feat.get_feature_names(X.columns), selector.ranking_):
    print(name, rank)"""
X_train, X_test, y_train, y_test=train_test_split(X_poly[:,selector.support_], y, test_size=0.3, random_state=42)
clf_pts=LinearRegression().fit(X_train, y_train)
y_pred=clf_pts.predict(X_test)

performance_prints(clf_pts, X_train, X_test, y_train, y_test)
# Out:
# Training performance (R^2): 0.866
# Testing performance (R^2): 0.867
# R^2 cross val mean: 0.863
# 95% confidence interval for R^2: (0.844, 0.882)
# Mean Squared Error (MSE): 4.309
#
# Some test prints:
# Actual: 2.20	  Predicted: 3.23	Difference (absolute): 1.035
# Actual: 10.20	  Predicted: 10.89	Difference (absolute): 0.690
# Actual: 3.20	  Predicted: 4.21	Difference (absolute): 1.015
# Actual: 16.50	  Predicted: 12.67	Difference (absolute): 3.826
# Actual: 2.30	  Predicted: 3.32	Difference (absolute): 1.018
# Actual: 3.80	  Predicted: 4.87	Difference (absolute): 1.073
# Actual: 6.40	  Predicted: 13.16	Difference (absolute): 6.755
# Actual: 7.90	  Predicted: 8.48	Difference (absolute): 0.578
# Actual: 10.60	  Predicted: 10.80	Difference (absolute): 0.198
# Actual: 17.00	  Predicted: 19.31	Difference (absolute): 2.313
# Actual: 1.00	  Predicted: 1.20	Difference (absolute): 0.201
# Actual: 6.40	  Predicted: 5.79	Difference (absolute): 0.611
# Actual: 1.60	  Predicted: 2.69	Difference (absolute): 1.088
# Actual: 2.40	  Predicted: 3.37	Difference (absolute): 0.967
# Actual: 10.00	  Predicted: 7.87	Difference (absolute): 2.125
# Actual: 6.20	  Predicted: 4.96	Difference (absolute): 1.237
# Actual: 13.40	  Predicted: 14.83	Difference (absolute): 1.426
# Actual: 11.10	  Predicted: 11.54	Difference (absolute): 0.439
# Actual: 5.90	  Predicted: 6.10	Difference (absolute): 0.197
# Actual: 8.70	  Predicted: 5.88	Difference (absolute): 2.817

# %%
X_poly=PolynomialFeatures(degree=3).fit_transform(X)
y=player_data_df["PTS"]
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)

feats=SFS(LinearRegression(), k_features=15, forward=True, scoring='neg_mean_squared_error', cv=5).fit(X_train, y_train)

X_train, X_test, y_train, y_test=train_test_split(X_poly[:,feats.k_feature_idx_], y, test_size=0.3, random_state=42)
clf_pts=LinearRegression().fit(X_train, y_train)
y_pred=clf_pts.predict(X_test)
           
performance_prints(clf_pts, X_train, X_test, y_train, y_test)
my_resid_plot(y_test, y_pred, label_name="PTS")
# Out:
# Training performance (R^2): 0.866
# Testing performance (R^2): 0.868
# R^2 cross val mean: 0.863
# 95% confidence interval for R^2: (0.845, 0.881)
# Mean Squared Error (MSE): 4.295
#
# Some test prints:
# Actual: 2.20	  Predicted: 3.68	Difference (absolute): 1.484
# Actual: 10.20	  Predicted: 10.97	Difference (absolute): 0.769
# Actual: 3.20	  Predicted: 4.17	Difference (absolute): 0.975
# Actual: 16.50	  Predicted: 12.48	Difference (absolute): 4.020
# Actual: 2.30	  Predicted: 3.04	Difference (absolute): 0.742
# Actual: 3.80	  Predicted: 4.82	Difference (absolute): 1.019
# Actual: 6.40	  Predicted: 12.95	Difference (absolute): 6.552
# Actual: 7.90	  Predicted: 8.31	Difference (absolute): 0.408
# Actual: 10.60	  Predicted: 10.79	Difference (absolute): 0.185
# Actual: 17.00	  Predicted: 19.59	Difference (absolute): 2.588
# Actual: 1.00	  Predicted: 1.40	Difference (absolute): 0.405
# Actual: 6.40	  Predicted: 5.64	Difference (absolute): 0.764
# Actual: 1.60	  Predicted: 2.59	Difference (absolute): 0.991
# Actual: 2.40	  Predicted: 3.69	Difference (absolute): 1.293
# Actual: 10.00	  Predicted: 7.78	Difference (absolute): 2.222
# Actual: 6.20	  Predicted: 4.87	Difference (absolute): 1.326
# Actual: 13.40	  Predicted: 14.72	Difference (absolute): 1.323
# Actual: 11.10	  Predicted: 11.57	Difference (absolute): 0.467
# Actual: 5.90	  Predicted: 6.02	Difference (absolute): 0.123
# Actual: 8.70	  Predicted: 5.74	Difference (absolute): 2.963

# %% [markdown]
# ## Assists per Game (AST column) Model

# %%
print(player_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3925 entries, 0 to 4395
# Data columns (total 14 columns):
# 2PA              3925 non-null float64
# 3P               3925 non-null float64
# AST              3925 non-null float64
# Age              3925 non-null int64
# BLK              3925 non-null float64
# Draft Placing    3925 non-null float64
# MP               3925 non-null float64
# PF               3925 non-null float64
# PTS              3925 non-null float64
# STL              3925 non-null float64
# TOV              3925 non-null float64
# TRB              3925 non-null float64
# US or EU         3925 non-null object
# eFG%             3925 non-null float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 620.0+ KB
# None

# %%
y=player_data_df["AST"]
X_poly=PolynomialFeatures(degree=2).fit_transform(X)
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_ast=LinearRegression().fit(X_train, y_train)
y_pred=clf_ast.predict(X_test)

# GridSearchCV(Lasso(max_iter=2000), param_grid={"alpha":[1e-5,1e-1,1,10,1e3,1e5]}).fit(X_train, y_train)
print("Training performance (R^2): %.3f" % clf_ast.score(X_train, y_train))
print("Testing performance (R^2): %.3f" % clf_ast.score(X_test, y_test))
scores=cross_val_score(clf_ast, X_poly, y, cv=5)
print("R^2 cross val mean: %.3f" % (scores.mean()))
print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

for idx, data in enumerate(zip(y_test, y_pred)): 
    if idx<20:
        print("Actual: %.2f\t     Predicted: %.2f     Difference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
# Out:
# Training performance (R^2): 0.623
# Testing performance (R^2): 0.591
# R^2 cross val mean: 0.598
# 95% confidence interval for R^2: (0.555, 0.640)
# Mean Squared Error (MSE): 0.353
#
# Some test prints:
# Actual: 0.30	     Predicted: 0.42     Difference (absolute): 0.125
# Actual: 0.80	     Predicted: 1.35     Difference (absolute): 0.549
# Actual: 0.30	     Predicted: 0.49     Difference (absolute): 0.187
# Actual: 3.40	     Predicted: 1.65     Difference (absolute): 1.745
# Actual: 0.30	     Predicted: 0.47     Difference (absolute): 0.166
# Actual: 0.90	     Predicted: 0.75     Difference (absolute): 0.149
# Actual: 1.30	     Predicted: 2.01     Difference (absolute): 0.714
# Actual: 0.70	     Predicted: 1.05     Difference (absolute): 0.351
# Actual: 0.70	     Predicted: 1.80     Difference (absolute): 1.103
# Actual: 1.50	     Predicted: 2.18     Difference (absolute): 0.678
# Actual: 0.10	     Predicted: 0.22     Difference (absolute): 0.123
# Actual: 0.20	     Predicted: 0.56     Difference (absolute): 0.355
# Actual: 0.20	     Predicted: 0.39     Difference (absolute): 0.193
# Actual: 0.40	     Predicted: 0.47     Difference (absolute): 0.066
# Actual: 1.30	     Predicted: 0.89     Difference (absolute): 0.405
# Actual: 1.10	     Predicted: 0.53     Difference (absolute): 0.572
# Actual: 2.60	     Predicted: 1.87     Difference (absolute): 0.727
# Actual: 1.20	     Predicted: 1.69     Difference (absolute): 0.492
# Actual: 0.70	     Predicted: 0.60     Difference (absolute): 0.099
# Actual: 1.30	     Predicted: 0.61     Difference (absolute): 0.693

# %%
residuals=y_test-y_pred
plt.scatter(y_pred, residuals, color="black")
plt.title("Residual Plot")
plt.xlabel("Predicted AST Values")
plt.ylabel("Residuals")
plt.axhline(y=0, linewidth=3, color="black")
plt.show()

# %%
y=player_data_df["AST"]
X_poly=PolynomialFeatures(degree=1).fit_transform(player_data_df.iloc[:,[0,1,3,4,5,6,7,8,9,10,11,13]])
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_ast=LinearRegression().fit(X_train, y_train)
y_pred=clf_ast.predict(X_test)

#GridSearchCV(Lasso(max_iter=2000), param_grid={"alpha":[1e-5,1e-1,1,10,1e3,1e5]}).fit(X_train, y_train)
print("Training performance (R^2): %.3f" % clf_ast.score(X_train, y_train))
print("Testing performance (R^2): %.3f" % clf_ast.score(X_test, y_test))
scores=cross_val_score(clf_ast, X_poly, y, cv=5)
print("R^2 cross val mean: %.3f" % (scores.mean()))
print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

for idx, data in enumerate(zip(y_test, y_pred)): 
    if idx<20:
        print("Actual: %.2f\t     Predicted: %.2f     Difference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
# Out:
# Training performance (R^2): 0.704
# Testing performance (R^2): 0.687
# R^2 cross val mean: 0.685
# 95% confidence interval for R^2: (0.617, 0.752)
# Mean Squared Error (MSE): 0.271
#
# Some test prints:
# Actual: 0.30	     Predicted: 0.48     Difference (absolute): 0.176
# Actual: 0.80	     Predicted: 0.89     Difference (absolute): 0.088
# Actual: 0.30	     Predicted: 0.56     Difference (absolute): 0.256
# Actual: 3.40	     Predicted: 2.40     Difference (absolute): 0.995
# Actual: 0.30	     Predicted: 0.28     Difference (absolute): 0.016
# Actual: 0.90	     Predicted: 0.93     Difference (absolute): 0.027
# Actual: 1.30	     Predicted: 1.29     Difference (absolute): 0.009
# Actual: 0.70	     Predicted: 1.23     Difference (absolute): 0.532
# Actual: 0.70	     Predicted: 1.55     Difference (absolute): 0.847
# Actual: 1.50	     Predicted: 2.32     Difference (absolute): 0.819
# Actual: 0.10	     Predicted: 0.01     Difference (absolute): 0.089
# Actual: 0.20	     Predicted: 0.51     Difference (absolute): 0.305
# Actual: 0.20	     Predicted: 0.35     Difference (absolute): 0.152
# Actual: 0.40	     Predicted: 0.38     Difference (absolute): 0.021
# Actual: 1.30	     Predicted: 1.32     Difference (absolute): 0.025
# Actual: 1.10	     Predicted: 1.12     Difference (absolute): 0.019
# Actual: 2.60	     Predicted: 2.70     Difference (absolute): 0.097
# Actual: 1.20	     Predicted: 1.78     Difference (absolute): 0.580
# Actual: 0.70	     Predicted: 0.47     Difference (absolute): 0.235
# Actual: 1.30	     Predicted: 1.00     Difference (absolute): 0.302

# %%
residuals=y_test-y_pred
plt.scatter(y_pred, residuals, color="black")
plt.title("Residual Plot")
plt.xlabel("Predicted AST Values")
plt.ylabel("Residuals")
plt.axhline(y=0, linewidth=3, color="black")
plt.show()

# %% [markdown]
# **INSERT ASSIST COMMENTS HERE**

# %% [markdown]
# ## Total Rebounds per Game (TRB column) Model

# %%
y=player_data_df["TRB"]
X_poly=PolynomialFeatures(degree=2).fit_transform(X)
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_trb=LinearRegression()
clf_trb.fit(X_train, y_train)
y_pred=clf_trb.predict(X_test)

print("Training performance (R^2): %.3f" % clf_trb.score(X_train, y_train))
print("Testing performance (R^2): %.3f" % clf_trb.score(X_test, y_test))
scores=cross_val_score(clf_trb, X_poly, y, cv=5)
print("R^2 cross val mean: %.3f" % (scores.mean()))
print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

for idx, data in enumerate(zip(y_test, y_pred)): 
    if idx<20:
        print("Actual: %.2f\t     Predicted: %.2f     Difference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
# Out:
# Training performance (R^2): 0.841
# Testing performance (R^2): 0.843
# R^2 cross val mean: 0.835
# 95% confidence interval for R^2: (0.816, 0.854)
# Mean Squared Error (MSE): 1.384
#
# Some test prints:
# Actual: 2.40	     Predicted: 2.48     Difference (absolute): 0.075
# Actual: 7.80	     Predicted: 6.72     Difference (absolute): 1.081
# Actual: 3.50	     Predicted: 3.24     Difference (absolute): 0.256
# Actual: 9.20	     Predicted: 7.79     Difference (absolute): 1.412
# Actual: 4.40	     Predicted: 2.73     Difference (absolute): 1.674
# Actual: 3.60	     Predicted: 3.89     Difference (absolute): 0.286
# Actual: 6.10	     Predicted: 7.74     Difference (absolute): 1.642
# Actual: 5.40	     Predicted: 6.08     Difference (absolute): 0.684
# Actual: 8.50	     Predicted: 6.94     Difference (absolute): 1.563
# Actual: 12.50	     Predicted: 10.62     Difference (absolute): 1.881
# Actual: 0.90	     Predicted: 0.95     Difference (absolute): 0.050
# Actual: 4.10	     Predicted: 4.19     Difference (absolute): 0.089
# Actual: 1.90	     Predicted: 2.38     Difference (absolute): 0.484
# Actual: 2.50	     Predicted: 2.75     Difference (absolute): 0.250
# Actual: 5.20	     Predicted: 5.48     Difference (absolute): 0.282
# Actual: 2.90	     Predicted: 3.68     Difference (absolute): 0.777
# Actual: 4.20	     Predicted: 8.53     Difference (absolute): 4.327
# Actual: 8.50	     Predicted: 8.22     Difference (absolute): 0.275
# Actual: 4.90	     Predicted: 4.48     Difference (absolute): 0.423
# Actual: 2.90	     Predicted: 4.35     Difference (absolute): 1.447

# %%
residuals=y_test-y_pred
plt.scatter(y_pred, residuals, color="black")
plt.title("Residual Plot")
plt.xlabel("Predicted TRB Values")
plt.ylabel("Residuals")
plt.axhline(y=0, linewidth=3, color="black")
plt.show()

# %% [markdown]
# Like in the PTS model case, the residuals are roughly randomly distributed, however for higher predicted values we see a larger variance in the residuals.

# %% [markdown]
# ## Blocks per Game (BLK column) Model

# %%
y=player_data_df["BLK"]
X_poly=PolynomialFeatures(degree=2).fit_transform(X)
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_blk=LinearRegression()
clf_blk.fit(X_train, y_train)
y_pred=clf_blk.predict(X_test)

print("Training performance (R^2): %.3f" % clf_blk.score(X_train, y_train))
print("Testing performance (R^2): %.3f" % clf_blk.score(X_test, y_test))
scores=cross_val_score(clf_blk, X_poly, y, cv=5)
print("R^2 cross val mean: %.3f" % (scores.mean()))
print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

for idx, data in enumerate(zip(y_test, y_pred)): 
    if idx<20:
        print("Actual: %.2f\t     Predicted: %.2f     Difference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
# Out:
# Training performance (R^2): 0.422
# Testing performance (R^2): 0.390
# R^2 cross val mean: 0.353
# 95% confidence interval for R^2: (0.233, 0.474)
# Mean Squared Error (MSE): 0.314
#
# Some test prints:
# Actual: 0.20	     Predicted: 0.35     Difference (absolute): 0.151
# Actual: 2.00	     Predicted: 1.11     Difference (absolute): 0.889
# Actual: 0.50	     Predicted: 0.47     Difference (absolute): 0.025
# Actual: 1.10	     Predicted: 1.19     Difference (absolute): 0.095
# Actual: 0.70	     Predicted: 0.35     Difference (absolute): 0.354
# Actual: 0.20	     Predicted: 0.62     Difference (absolute): 0.417
# Actual: 0.90	     Predicted: 1.14     Difference (absolute): 0.244
# Actual: 0.60	     Predicted: 0.96     Difference (absolute): 0.358
# Actual: 0.50	     Predicted: 0.95     Difference (absolute): 0.453
# Actual: 1.30	     Predicted: 1.74     Difference (absolute): 0.442
# Actual: 0.10	     Predicted: 0.11     Difference (absolute): 0.013
# Actual: 1.70	     Predicted: 0.75     Difference (absolute): 0.951
# Actual: 0.80	     Predicted: 0.33     Difference (absolute): 0.475
# Actual: 0.70	     Predicted: 0.38     Difference (absolute): 0.317
# Actual: 0.30	     Predicted: 0.91     Difference (absolute): 0.611
# Actual: 0.10	     Predicted: 0.62     Difference (absolute): 0.518
# Actual: 0.80	     Predicted: 1.33     Difference (absolute): 0.526
# Actual: 1.60	     Predicted: 1.28     Difference (absolute): 0.316
# Actual: 0.80	     Predicted: 0.76     Difference (absolute): 0.041
# Actual: 0.20	     Predicted: 0.72     Difference (absolute): 0.519

# %%
residuals=y_test-y_pred
plt.scatter(y_pred, residuals, color="black")
plt.title("Residual Plot")
plt.xlabel("Predicted BLK Values")
plt.ylabel("Residuals")
plt.axhline(y=0, linewidth=3, color="black")
plt.show()

# %% [markdown]
# This is totally horrible, we need to do something different.

# %% [markdown]
# ## Steals per Game (STL column) Model

# %%
y=player_data_df["STL"]
X_poly=PolynomialFeatures(degree=2).fit_transform(X)
X_train, X_test, y_train, y_test=train_test_split(X_poly, y, test_size=0.3, random_state=42)
clf_stl=LinearRegression()
clf_stl.fit(X_train, y_train)
y_pred=clf_stl.predict(X_test)

print("Training performance (R^2): %.3f" % clf_stl.score(X_train, y_train))
print("Testing performance (R^2): %.3f" % clf_stl.score(X_test, y_test))
scores=cross_val_score(clf_stl, X_poly, y, cv=5)
print("R^2 cross val mean: %.3f" % (scores.mean()))
print("95%% confidence interval for R^2: (%.3f, %.3f)" % (scores.mean()-scores.std()*2, scores.mean()+scores.std()*2))
print("Mean Squared Error (MSE): %.3f\n\nSome test prints:" % mean_squared_error(y_test, y_pred))

for idx, data in enumerate(zip(y_test, y_pred)): 
    if idx<20:
        print("Actual: %.2f\t     Predicted: %.2f     Difference (absolute): %.3f" % (data[0], data[1], np.abs(data[0]-data[1])))
# Out:
# Training performance (R^2): 0.593
# Testing performance (R^2): 0.532
# R^2 cross val mean: 0.556
# 95% confidence interval for R^2: (0.447, 0.665)
# Mean Squared Error (MSE): 0.057
#
# Some test prints:
# Actual: 0.40	     Predicted: 0.26     Difference (absolute): 0.136
# Actual: 0.70	     Predicted: 0.67     Difference (absolute): 0.027
# Actual: 0.30	     Predicted: 0.32     Difference (absolute): 0.017
# Actual: 1.00	     Predicted: 0.73     Difference (absolute): 0.268
# Actual: 0.10	     Predicted: 0.26     Difference (absolute): 0.162
# Actual: 0.50	     Predicted: 0.45     Difference (absolute): 0.055
# Actual: 0.90	     Predicted: 0.84     Difference (absolute): 0.060
# Actual: 1.10	     Predicted: 0.56     Difference (absolute): 0.537
# Actual: 0.40	     Predicted: 0.74     Difference (absolute): 0.339
# Actual: 1.10	     Predicted: 0.91     Difference (absolute): 0.187
# Actual: 0.00	     Predicted: 0.09     Difference (absolute): 0.086
# Actual: 0.30	     Predicted: 0.39     Difference (absolute): 0.092
# Actual: 0.40	     Predicted: 0.26     Difference (absolute): 0.143
# Actual: 0.20	     Predicted: 0.28     Difference (absolute): 0.084
# Actual: 0.70	     Predicted: 0.52     Difference (absolute): 0.184
# Actual: 0.50	     Predicted: 0.35     Difference (absolute): 0.146
# Actual: 1.40	     Predicted: 0.80     Difference (absolute): 0.599
# Actual: 0.70	     Predicted: 0.72     Difference (absolute): 0.019
# Actual: 0.40	     Predicted: 0.40     Difference (absolute): 0.004
# Actual: 0.30	     Predicted: 0.40     Difference (absolute): 0.100

# %%
residuals=y_test-y_pred
plt.scatter(y_pred, residuals, color="black")
plt.title("Residual Plot")
plt.xlabel("Predicted STL Values")
plt.ylabel("Residuals")
plt.axhline(y=0, linewidth=3, color="black")
plt.show()

# %% [markdown]
# This also doesn't perform ideally.
